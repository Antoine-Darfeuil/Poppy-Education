# %% [markdown]
# <img src="image/Dico/logo-snap!.png" alt="Blablabla" style="height: 50px;"/>
# # Documentation simple et accessible à tous (en *très lourde* construction)
# # - pour l'éducation -
# -\*- _et en français !_ -\*-
#
#
# ## Introduction (en construction)
#
# Le but de ce **dictionnaire** est d'expliquer la fonction de *tous* **les blocs robot Poppy** Snap!<br />
# Ce dictionnaire s'adresse _en particulier_ aux **personnes novice dans l'utilisation de Snap!** et **non familère avec la robotique ou la programmation**.<br />
#
# Il fait parti d'une série de document d'aide pour Snap! et l'initiation à la robotique avec _Poppy_ :<br />
# * Lexique du jargon utilisé
# * Fiche moteurs Poppy
# * *Dictionnaire des blocs Snap! (?)* --> _ndl : très très long à réaliser_
# * Dictionnaire des blocs Snap! pour Poppy
# * Décrouvir Snap!
# * Les notions avancées de Snap! _(ou de comment créer ses propres blocs et autres histoires)_ --> _ndl : très long à réaliser_
#
# A noté que, si l'interface de Snap! peux être affiché en français (les nom des blocs étant alors également en français), les *blocs robot Poppy* sous snap! sont en *langue anglaise* et *les aides* correspondantes également.<br />
# C'est un choix éducatif que de ne pas avoir traduit ses blocs. En effet, l'apprentissage de certaines notions d'anglais est ... dans ces domaine aujourd'hui<br />
#
# Les explications dasn la suite sont donc données en _langues_ **française** et **anglaise**.<br /> _bla bla bla_

# %% [markdown]
# ------
#
# ---
#
# ---
#
# ## Lexique
#
# **- C -**
# * **Compliant** (_anglicisme_) : accommodant, docile. Traduit le fait que les moteurs soient libres (non bloqués) et puissent être manipulés sans efforts. Contraire : non-compliant
#
# * **Concurent :**
#
# **- L -**
# * **Listes :**
# * **Librairie :**
#
# **- P -**
# * **Primitive :** ensemble de commandes envoyer aux moteurs de façon périodique ou non.
#
# **- S -**
# * **Séquentiel : **
#
# **- V -**
# * **Variables :**

# %% [markdown]
# * * * * * * * * * * * *
#
# ---
#
# ---

# %% [markdown]
# <img src="image/Dico/logo-snap!.png" alt="Blablabla" style="height: 100px;"/>
#
# # Decouvrir Snap!
#
# _ici on decouvre Snap! en français !_
#
#
# ## 1. Introduction - Qu'est ce que Snap!
#
# ### 2. L'interface de Snap!
#
#
#
# ## 2. La programmation par blocs !
#
# ### 1. Les types de blocs :
#
# Il existe 4 types de blocs Snap! :
#
# Blocs de commandes | Blocs de XXWXX | Blocs XXXXWX | Blocs chapeaux
# ---|---
# _Command blocks_ | _Reporter blocks_ | _..._ | _Hat blocks_
# ex : | ex : | ex : | ex :
# Rectangulaire | Arrondi | Triangulaire | Ondulé
# Permet d'exécuter une action | Ne lance pas d’action mais retournent une ou plusieurs valeurs ou informations pouvant servir d’entrée à un autre bloc. Ce type de blocs comprend entre autres les variables | ... | Se positionne au sommet d’une suite d’instruction et permettent de gérer le lancement de celle-ci
#
# ### 2. Les différentes catégories de blocs :
#
# Les blocs de Snap ! sont accessibles depuis la palette de blocs et rangés au sein de **8 grandes catégories**, suivant leurs fonctions  :
#
# <img src="image/Snap/categories.png" alt="Blablabla" style="height: 100px;"/>
#
# A chaque catégorie correspond une couleur spécifique
#
#
#
#
# * **Motion (Mouvement)** : regroupe l’ensemble des blocs nécessaires pour faire ce mouvoir les lutins sur la scène.<br /> _(ex : avancer de 10 pas, glisser au point de coordonnées x y , …)_
#
# * **Looks (Aspect)** : regroupe l’ensemble des blocs permettant de gérer l’apparence des lutin et de la scène.<br />
# _(ex : changer le costume actuel pour  costume_2, costume suivant, afficher, masquer, …)_
#
# * **Sound (Son)** : regroupe l’ensemble des blocs permettent de faire jouer à snap ! un son ou une note.<br />
# _(ex : jouer le son …, jouer la note 60 pendant 2 temps, …)_
#
# * **Pen (Stylo)** : regroupe l’ensemble des blocs permettant de dessiner, tracer des traits sur la scène.
#
# * **Control (Contrôle)** : regroupe l’ensemble des blocs permettant le contrôle des différentes blocs de commandes ; en particulier cette catégorie contient les actions logiques comme les boucles, les conditions, …
#
# * **Sensing (Capteur)** : regroupe l’ensemble des blocs permettant simuler des captXXXXX.
#
# * **Operators (Opérateurs)** : regroupe l’ensemble des opérateurs logiques
#
# * **Variables (Variables)** : regroupe l’ensemble des fonctions sur les variables et les listes.
#
#
#
#
#
# * Les blocs spécifiques à Poppy («Ctrl + f ») : regroupe l’ensembles des blocs crées spécifiquement pour Poppy.
#
#
# ### 3. Les blocs de base :
#
#
# ### 4. Un premier programme :
#
#
#
#
# ## 3. Utilisation de Snap! pour découvrir la robotique avec Poppy
#
# ##  Introduction
#
# _Bla bla bla et mondanité_
# _où l'on explique la potentialité de Snap! avec Poppy_
# _où l'on explique les différentes oportunités possibles_
#
# --> **comment utiliser poppy et snap! pour découvrir la robotique, la programmation et plus encore ... [EXPLIQUE]**
#
#
# ## A.  Les blocs utiles au démarrage :
#
#
#
#
# ## B. Programmer les mouvements de Poppy - (*Blocs de base*) :
# ## C. Les mouvement par démonstration - _(Enregistrer et rejouer des mouvements)_
# ## D. Exploiter les primitives
# ## E. Des exemples d'applications

# %% [markdown]
# ---
#
# ---
#
# ---

# %% [markdown]
# # Dictionnaires des blocs _robot Poppy_
#
# ---
# ### Les blocs de type *Reporters* :
#
# Code | BlocSnap! _robot poppy_ | Fonction
# ----------|----------
# R1|<img src="image/Dico/motors-from-alias.png" alt="Blablabla" style="height: 15x;"/>|Retourne la liste des motors correspondant à l'alias donné
# R2|<img src="image/Dico/all-motors.png" alt="Blablabla" style="height: 15px;"/>|Retourne la liste de tous les moteurs
# R3|<img src="image/Dico/get-motor-present-position.png" alt="Blablabla" style="height: 15x;"/>|Retourne la valeur _(en degrée)_ de la position _(angle)_ du moteur donné
# R4|<img src="image/Dico/get-motor-register.png" alt="Blablabla" style="height: 15x;"/>|Retourne la valeur du registre <sup>1</sup> demandé sur moteur donné
# R5|<img src="image/Dico/index-of-motor.png" alt="Blablabla" style="height: 15x;"/>|Retourne l'indexe du moteur donné
# R6|<img src="image/Dico/server.png" alt="Blablabla" style="height: 15x;"/>| ????????
# R7|<img src="image/Dico/all-records.png" alt="Blablabla" style="height: 15x;"/>|Retourne la liste de tous les mouvements enregistrés
# R8|<img src="image/Dico/get-all-primitives.png" alt="Blablabla" style="height: 15px;"/>|Retourne le liste de toutes les primitives
# R9|<img src="image/Dico/all-aliases.png" alt="Blablabla" style="height: 15px;"/>|Retourne la liste de tous les alias
# R10|<img src="image/Dico/test-connection.png" alt="Blablabla" style="height: 15px;"/>|Tester la connexion avec v-rep ou Poppy
# R11|<img src="image/Dico/get-methodes-of-primitive.png" alt="Blablabla" style="height: 15px;"/>|Retourne ??? of primitives
#
#
# ---
# ### Les blocs de type *Commands* :
#
# Code | BlocSnap! _robot poppy_ | Fonction
# ----------|----------
# C1|<img src="image/Dico/set-motor-compliant.png" alt="Blablabla" style="height: 20px;"/>|Rendre le ou les moteurs compliant (ou non-compliant)
# C2|<img src="image/Dico/motor-go-to-position.png" alt="Blablabla" style="height: 20px;"/>|Mettre le ou les moteurs à la position
# C3|<img src="image/Dico/reset-simulation.png" alt="Blablabla" style="height: 20px;"/>|Réinitialiser la simulation _(bloc spécifique à la simulation avec v-rep)_
# C4|<img src="image/Dico/set-motor-register-to.png" alt="Blablabla" style="height: 20px;"/>|Definir le registre du moteur donné
# C5|<img src="image/Dico/start-record.png" alt="Blablabla" style="height: 20px;"/>|Commencer l'enregistrement d'un mouvement _(bloc spécifique au mouvement par démonstration)_
# C6|<img src="image/Dico/creat-move-with-motor.png" alt="Blablabla" style="height: 20px;"/>|Creér un nouveau mouvement avec le(s) moteur(s) donné(s) <br /> _(bloc spécifique au mouvement par démonstration)_
# C7|<img src="image/Dico/stop-record-move.png" alt="Blablabla" style="height: 20px;"/>|Arrêter l'enregistrement du mouvement _(bloc spécifique au mouvement par démonstration)_
# C8|<img src="image/Dico/stop-play-move.png" alt="Blablabla" style="height: 20px;"/>|Arrêter de jouer le mouvement en cours _(bloc spécifique au mouvement par démonstration)_
# C9|<img src="image/Dico/start-primitive.png" alt="Blablabla" style="height: 20px;"/>|Lancer une primitives
#
# ---
#
# ### Les blocs spécialisés dans les *Mouvements par démonstration* :
#
# Bien que de type *reporters*, c'est blocs sont un peu particulier puisqu'ils sont pensés comme des commandes (qu'il faut alors lancer avec le bloc de commande *Run* (dans les blocs de controle) :
#
# Code | BlocSnap! _robot poppy_ | Fonction
# ----------|----------
# M1|<img src="image/Dico/play-move-speed.png" alt="Blablabla" style="height: 15px;"/>|
# M2|<img src="image/Dico/sequential.png" alt="Blablabla" style="height: 15px;"/>| ?
# M3|<img src="image/Dico/concurent.png" alt="Blablabla" style="height: 15px;"/>| ?
# M4|<img src="image/Dico/play-concurently-moves.png" alt="Blablabla" style="height: 15px;"/>|
# M5|<img src="image/Dico/play-sequentialy-moves.png" alt="Blablabla" style="height: 15px;"/>|
# M6|<img src="image/Dico/play-in-reverse-move-speed.png" alt="Blablabla" style="height: 15px;"/>|

# %% [markdown]
# ---
# ### R1 : Retourne la liste des motors correspondant à l'alias donné
# **_Help :_**
# Return a list of motors which are grouped in the input alias.
#
#
# ** _Aide :_ **
#
# ---
# ### R2 : Retourne la liste de tous les moteurs
# **_Help :_**
# Return a list of all available motors.
#
# ** _Aide :_ **
#
# ---
# ### R3 : Retourne la valeur (en degrée) de la position (angle) du moteur donné
#
# **_Help :_**
# Get the present position (angle) of the defined < motor \>.
#
#
# ** _Aide :_ **
#
# ---
# ### R4 : Retourne la valeur du registre demandé sur moteur donné
#
# **_Help :_**
# Get a defined < register > < value > of one motor. <br />
# Exemple of some registers : torque_limit, angle_limit, present_temperature, present_position ...<br />
# For more information about registers, look at the online documentation : [Go to pypot documentation](http://poppy-project.github.io/pypot/)
#
# ** _Aide :_ **
#
#
#
# ---
# ### R5 : Retourne l'indexe du moteur donné
# **_Help :_**
# Return the index of a motor name in the "robot all motors" block list.
#
# ** _Aide :_ **
#
#
# ---
# ### R6 : ????????
# **_Help :_** _void_
#
# ** _Aide :_ ** Aucune documentation disponible
#
# ---
# ### R7 : Retourne la liste de tous les mouvements enregistrés
# **_Help :_**
# Return a list of all previous records filename.
#
# ** _Aide :_ **
#
# ---
# ### R8 : Retourne le liste de toutes les primitives
# **_Help :_** _void_
#
# ** _Aide :_ **
#
# ---
# ### R9 : Retourne la liste de tous les alias
# **_Help :_**
# Return a list of all aliases. <br /> Alias is a keyword for representing many motors at once.
#
# ** _Aide :_ **
#
# ---
# ### R10 :  **Tester la connexion avec v-rep ou Poppy**
# **Help :**
# Report one of the following messages :
# * Connection ok!
# * You may have connection troubles. Check the host variable
#
#
# **Aide :**
# Permet de tester l’état de la connexion snap! avec le _simulateur v-rep_ ou le _robot Poppy_. Renvoie le message “Connection ok!” si la connection est correctement établie.
#
# ---
# ### R11 : Retourne ??? of primitives
# **_Help :_** _void_
#
# ** _Aide :_ **

# %% [markdown]
# ---
#
# ---
# ### C1 **Rendre le ou les moteurs compliant (ou non-compliant)**
#
# <img src="image/Dico/set-motor-compliant.png" alt="Blablabla" style="height: 25px;"/>
#
# **_Help :_**
# Compliance property make motors activity become soft and movable.
# You need to activate the compliance if you want to record a movement by demonstration.
#
# The motor(s) input can accept :
# - string of a motor name
# - string of many motors separed with spaces
# - a Snap! list of motors like the reporter block “robot all motors”
#
# ** _Aide :_ **
# Cette instruction permet de rendre les moteurs indiqués compliant (ou non-compliant). Les moteurs “compliant” sont libres (non bloqués) et peuvent donc être manipulés sans efforts. Les moteurs non-compliant sont à l’invers bloqués dans la position qu’ils occupent ; c’est le mode par défaut lorsque le _robot Poppy_ est allumé.
#
#
# L’entrée de ce bloque peut être :
# - le nom d’un moteur
# - plusieurs noms de moteurs séparés par un “espace”
# - une liste snap! de noms de moteurs
#
# ** Remarque importante : **
# si rien n’est spécifié pour le nom des moteurs, l’instruction s’applique à tous les moteurs du robot.
#
# ** Utilisation : **
# Il est nécessaire d'utiliser cette instruction pour manipuler le robot Poppy sans endommager les moteurs. En particulier : il est nécessaire de rendre “compliant” les moteurs avec lesquels on souhaite travailler pour enregistrer des mouvements par démonstration.
#
# ---
# ### C2 ** Mettre le ou les moteurs à la position **
#
# <img src="image/Dico/motor-go-to-position.png" alt="Blablabla" style="height: 25px;"/>
#
# ** _Help :_ **
# Set motor to the desired position (angle) in the desired time.
#
# The motor(s) input can accept :
# - string of motor name
# - string of many motores separed with spaces
# - a snap! lis of motors like the reporter block “robot all motors”
#
# ** _Aide :_ **
# C’est la commande principale pour contrôler les mouvements de Poppy.
# Cette instruction permet de contrôler le moteur (ou les moteurs) indiqués via une indication de position à atteindre, en précisant le temps pour accomplir cette action.
# La position est un angle (en degrée) correspondant à position donnée autour de l’axe de rotation du moteur. (voir fiche moteurs)
#
# L’entrée de ce bloque peut être :
# - le nom d’un moteur
# - plusieurs noms de moteurs séparés par un “espace”
# - une liste snap! de noms de moteurs
#
# ** Utilisation : **
# Par défaut : le mouvements s'exécute en 0 secondes. Cependant les mouvements sont alors très brutaux et saccadés. Un temps de 2 secondes est très raisonnable en pratique
#
#
# ---
# ### C3 :  **Réinitialiser la simulation - Bloc spécifique à la simulation avec V-rep**
# <img src="image/Dico/reset-simulation.png" alt="Blablabla" style="height: 25px;"/>
#
# **_Help :_**
# Reset the simulation in V-rep.
# It is usefull if you have connection issues with v-rep.
#
# ** _Aide :_ **
# Cette instruction permet de réinitialiser la simulation. Elle est utile pour revenir à zéro après une mauvaise manipulation ou en cas de problème de connexions.
#
# ---
# ### C4 : Definir le registre du moteur donné
# <img src="image/Dico/set-motor-register-to.png" alt="Blablabla" style="height: 25px;"/>
# **_Help :_**
# Set a defined < value > to a defined < register > of one or many motors.<br />
# Exemple of some registers : torque_limit, angle_limit, safe_compliant, compliant,...<br />
# For more information about registers, look at the online documentation : [Go to pypot documentation](http://poppy-project.github.io/pypot/)
#
# The motor(s) input can accept :
# - string of motor name
# - string of many motores separed with spaces
# - a snap! lis of motors like the reporter block “robot all motors”
#
# ** _Aide :_ **
#
# ---
# ### C5 : Commencer l'enregistrement d'un mouvement - _(bloc spécifique au mouvement par démonstration)_
# <img src="image/Dico/start-record.png" alt="Blablabla" style="height: 25px;"/>
# **_Help :_**
# Start recording the desired move record.<br />
# _Be careful_, you may previously defined a move record with the "creat move .. with motor(s) ..." block.
#
# ** _Aide :_ **
#
# ---
# ### C6 : Creér un nouveau mouvement avec le(s) moteur(s) donné(s)
# <img src="image/Dico/creat-move-with-motor.png" alt="Blablabla" style="height: 25px;"/>
# **_Help :_**
# Define a move record with the desired motors.<br />
# The < record_name > input is used to store the record move. The move is stores in the directory where you started the web server (with the command "robot-snap robot-ergo" for example), and can be replayed even if you close Snap!.
#
# The motor(s) input can accept :
# - string of motor name
# - string of many motores separed with spaces
# - a snap! lis of motors like the reporter block “robot all motors”
#
# If the motor(s) input is empty, all motors will be recorded.
#
# ** _Aide :_ **
#
# ---
# ### C7 : Arrêter l'enregistrement du mouvement
# <img src="image/Dico/stop-record-move.png" alt="Blablabla" style="height: 25px;"/>
# **_Help :_**
# Stop recording the desired move record.<br />
# _Be careful_, you may previously defined a move record with the "creat move .. with motor(s) ..." block.
#
#
# ** _Aide :_ **
#
#
# ---
# ### C8 : Arrêter de jouer le mouvement en cours
# <img src="image/Dico/stop-play-move.png" alt="Blablabla" style="height: 25px;"/>
# **_Help :_** _void_
#
#
# ** _Aide :_ **
#
#
# ---
# ### C9 : Lancer une primitives
# <img src="image/Dico/start-primitive.png" alt="Blablabla" style="height: 25px;"/>
# **_Help :_** _void_
#
#
# ** _Aide :_ **

# %% [markdown]
# ---
#
# ---
# ### M1 :
# <img src="image/Dico/play-move-speed.png" alt="M1" style="height: 20px;"/>
# **_Help :_** Play the movement of a previous recorded move.<br />
# The < record_name > input is the name of a *.record* filename which should be in the same directory where you started the web server (with the command "robot-snap robot-ergo" for example).
#
# You can change the play speed with the < speed > input.
#
#
# ** _Aide :_ **
#
# ---
# ### M2 :
# <img src="image/Dico/sequential.png" alt="M2" style="height: 20px;"/>
# **_Help :_** _void_
#
#
# ** _Aide :_ **
#
# ---
# ### M3 :
# <img src="image/Dico/concurent.png" alt="M3" style="height: 20px;"/>
# **_Help :_** All reports input are run concurently. <br />
# You can use this block to play concurently many recorded move.
#
# ** _Aide :_ **
#
# ---
# ### M4
# <img src="image/Dico/play-concurently-moves.png" alt="M4" style="height: 20px;"/>
# **_Help :_** Play previous recorded move concurently.
#
# Inputs can be :
# * move name (string)
# * many moves name separated by whitespace
# * any reporter block like concurent or play concurently
#
#
# ** _Aide :_ **
#
# ---
# ### M5 :
# <img src="image/Dico/play-sequentialy-moves.png" alt="M5" style="height: 20px;"/>
# **_Help :_** Play previously recorded moves sequentialy.
#
# Inputs can be :
# * move name (string)
# * many moves name separated by whitespace
# * any reporter block like concurent or play concurently
#
# ** _Aide :_ **
#
# ---
# ### M6 :
# <img src="image/Dico/play-in-reverse-move-speed.png" alt="M6" style="height: 20px;"/>
#
# **_Help :_** Play in reverse th emovement of a previous recorded move.<br />
# The < record_name > input is the name of a *.record* filename which should be in the same directory where you started the web server (with the command "robot-snap robot-ergo" for example).
#
# You can change the play speed with the < speed > input.
#
#
#
# ** _Aide :_ **

# %% [markdown]
# ---
#
# ---
#
# # Tous les blocs _Poppy_ !
# ####_ou_
# ## _De l'admiration désintéressée des blocs_
#
# * Les blocs de type *Reporters* :
# <img src="image/Dico/motors-from-alias.png" alt="Blablabla" style="height: 15x;"/>
# <img src="image/Dico/all-motors.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/get-motor-present-position.png" alt="Blablabla" style="height: 15x;"/>
# <img src="image/Dico/get-motor-register.png" alt="Blablabla" style="height: 15x;"/>
# <img src="image/Dico/index-of-motor.png" alt="Blablabla" style="height: 15x;"/>
# <img src="image/Dico/server.png" alt="Blablabla" style="height: 15x;"/>
# <img src="image/Dico/all-records.png" alt="Blablabla" style="height: 15x;"/>
# <img src="image/Dico/get-all-primitives.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/all-aliases.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/test-connection.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/get-methodes-of-primitive.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/play-move-speed.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/sequential.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/concurent.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/play-concurently-moves.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/play-sequentialy-moves.png" alt="Blablabla" style="height: 15px;"/>
# <img src="image/Dico/play-in-reverse-move-speed.png" alt="Blablabla" style="height: 15px;"/>
# * * * * *
# * Les blocs de type *Commands* :
# <img src="image/Dico/set-motor-compliant.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/motor-go-to-position.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/reset-simulation.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/set-motor-register-to.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/start-record.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/creat-move-with-motor.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/stop-record-move.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/stop-play-move.png" alt="Blablabla" style="height: 20px;"/>
# <img src="image/Dico/start-primitive.png" alt="Blablabla" style="height: 20px;"/>

# %% [markdown]
# <table border="6">
#     <tr>
#         <th colspan="3"> Le super tabeau </th>
#
#     <tr>
#         <th> Code </th>
#         <th> Image </th>
#         <th> Text </th>
#     </tr>
#
#
#     <tr>
#         <td> # </td>
#         <td> une image </td>
#         <td> Un text qui explique le chemileblic<br />
#              Et plein d'autre trucs vraiment très interessant par ailleurs</td>
#     </tr>
#
# </table>

# %% [markdown]
# <p style="color:red">This is a paragraph.</p>
# <p style="font-family:courier">This is a paragraph.</p>
# <p style="font-size:160%">This is a paragraph.</p>
# <h1  style="text-align:center ; font-size:500% ; font-family:futura"> Dictionnaire des blocs </h1>
